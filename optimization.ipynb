# %% [markdown]
# **See notes on the types of optimization problems**

# %%
import opt_functions as opt

# %%
## Choose universe of stocks
universe = ["VOO", "BND", "MSFT", "VNQ"]

## Choose minimum and maximum weights for each stock
min_max_weights = {
    "VOO":  [0.1, 0.5],
    "BND":  [0.1, 0.6],
    "MSFT": [0.1, 0.3],
    "VNQ":  [0.0, 0.5],
}

opt_dict, start_date, end_date = opt.optimize(
                                        universe, 
                                        start_date="2023-01-01", 
                                        end_date="2024-01-01", 
                                        historical_returns=True, 
                                        min_max_weights=None, 
                                        short_selling=False, 
                                        risk_aversion=0.15, # little point of diversification
                                        # risk_aversion = 0.75, # risky 
                                        #risk_aversion = 3, # safe
                                        min_return=1.9
                                        )

opt.portfolio_performance(opt_dict, "2024-01-01", "2024-04-01", principal=200)
# Out:
# ______________Summary Predictions______________
#
#       Optimal Weights
# VOO            30.279
# BND             0.000
# MSFT           69.721
# VNQ             0.000
#
# Expected monthly returns: 3.36%
# Portfolio st.dev: 25.96
#
# __________________Summary G.T__________________
#
# Realized monthly returns (CMGR): 4.137%
# Simple rate of return: 12.88% over 0.25 year(s)
#
#   Low                    High
# $198.26 <------------> $228.9
#
# Final realized value: $225.77

# %%
import yfinance as yf

info = yf.Ticker("MSFT").basic_info
print(info)

balance_sheet = yf.Ticker("MSFT").balance_sheet
display(balance_sheet.head(50))
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']
#                                                         2023-06-30  \
# Ordinary Shares Number                                7432000000.0
# Share Issued                                          7432000000.0
# Net Debt                                             12533000000.0
# Total Debt                                           59965000000.0
# Tangible Book Value                                 128971000000.0
# Invested Capital                                    253460000000.0
# Working Capital                                      80108000000.0
# Net Tangible Assets                                 128971000000.0
# ...
